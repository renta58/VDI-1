# %% [markdown]
# CONTOH GOOD VISUALIZATION

# %% [markdown]
# ![image.png](attachment:d5599231-1b2e-4558-bbc1-4b8055e6d61f.png)

# %% [markdown]
# DIKATAKAN BAIK KARENA:

# %% [markdown]
# 1. Strive forms and Functions==> pada visualisasi diatas,form dan fungsinya berkesinambungan yang dimana form tersebut memberikan informasi terkait dengan data penduduk Sumatera Barat untuk setiap kota pada daerah povinsi tersebut dengan menggunakan diagram batang dan setiap diagram memberikan informasi untuk tiap kabupaten.
# 2. Justifying the selection of everything we do==> justifikasi dari pembuatan visualisasi ini cukup jelas dengan adanya alasan yang diberikan dalam pembuatan visualisasi ini karena menampilkan dengan jelas perbandingan dari setiap penduduk kabupaten melalui diagram batang.
# 3. Creating accessibility through intuitive design==> visualisai ini dapat dengan mudah dipahami oleh pembaca dan pengguna dari visualisasi karena pembuatan warna dari setiap diagram memberikan penjelasan terkait perbedaan kepadatan penduduk di setiap kabupaten. Serta diberikan keterangan yang menjelaskan hubungan dari warna-warna yang diberikan terhadap nama-nama kabupaten pada provinsi Sumatera Barat tersebut.
# 4. Never Deceive the receiver==>Penyampaian informasi melalui visualisasi tersebut cukup mudah dipahami dan memberikan informasi yang relevan terkait dengan skala jumlah penduduk terhadap setiap diagram batangnya.

# %% [markdown]
# ![image.png](attachment:959ee4b1-3eca-45af-a4ad-2979011f6ab5.png)

# %% [markdown]
# Dikatakan baik karena:

# %% [markdown]
# 1. Strive forms and Functions==> ada keseimbangan antara bentuk(form) yang diberikan dengan informasi yaitu tentang penjulan berdasarkan wilayah tertentu dan kategori produk yang dijual. Penggunaan form ini sangat cocok unutk menyampaikan informasinya karena dengan jelas menunjukkan perbedaan antar setiap wilayah dan kategorinya.
# 2. Justifying the selection of everything we do==> justifikasinya cukup jelas, pembuatan visualisasi ini memberikan alasan yang dapat memperlihatkan bagaiamana penjulan unutk 4 wilayah dan 3 kategori dengan penempatan atau peletakan dari setiap penjelasan yang tepat. Misalnya dengan warna yang berbeda untuk ke 4 wilayah akan tetapi warna yang sama untuk setiap wilayah yang sama sehingga pembaca lebih mudah juga juga dalama memahami jika warnanya sama,berarti terletak pada wilayah yang sama.
# 3. Creating accessibility through intuitive design==> mudah diakses oleh pengguna karen informasi yang diberikan sangat jelas dan visualisasinya sangat mudah unutk dipahami.
# 4. Never Deceive the Receiver ==> penyampaian informasi sangat jelas dan memberikan informasi yang relevan antara antara gambar diagram dengan perbandingan nilai yang terdapat didalamnya atau proporsi perbandingan untuk setiap diagram batang visualisasinya.

# %% [markdown]
# CONTOH BAD VISUALIZATION

# %% [markdown]
# ![image.png](attachment:289101c1-045d-47be-b13b-5e9be8abc558.png)

# %% [markdown]
# DIKATAKAN BURUK KARENA:
# 1. Strive forms and Functions==> bentuk dan fungsi cukup berkesinambungna. akan tetapi untuk informasi yang banyak,piechart kurang cocok untuk digunakan karena terkait dengan provinsi yang banyak di indonesia. sehingga ada bagian piechart yang sangat kecil dan tidak diketahui provinsi apakah itu dan adanya banyak warna yang mirip sehingga sulit untuk membedakan dan mengetahui suatu bagian tertentu apakah informasi yang terkandung didalamnya.
# 2.
# Justifying the selection of eveyithing we do==> justifikasi pembuatan kurang jelas,karena dapat menyebabkan kehilangan sebagian informasi kareanaahnya 4 provinsi saja yang diberikan jumlah pesenn provinsinya dari sekian banyak provinsi yang ikut divisualisasika dan jumlah dari keseluruhan penduduk juga tidak diberitahukan sehingga user tidak dapat mengetahui 18,7% itu sebanyak berapa jiwa. n3.
# Creating accessibility through intuitive design==> kurang mudah diakses karena banyaknya warna yang miridenganpi ukurannya yang sama-sama kecil juga sehingga masih kurang infomasi yang bisa didapatk.a4. neverVEeceive the ReceiverVER visualisasi tersebut tidak membohongi tetapi masih kurang jelas dan lengkaap dlam memberi/menyampaikankan inform yang terkandung di dalam visualisasi tersebut.asi

# %% [markdown]
# ![image.png](attachment:2bce7435-ca3a-4218-8776-d94bf6a9f2f0.png)

# %% [markdown]
# DIKATAKAN BURUK KARENA:

# %% [markdown]
# 1. Strive forms and Functions==> form(bentuk) dan fungsi yang digunakan kurang berkesinambungan karena informasi yang diberikan kurang jelas,infromasi yang diberikan tentang profit dari tipe product hanya pada desember 2011,june 2012,desember 2012, juni 2013 dan desember 2013 sehingga tidak dapat memberikan informasi yang cukup akurat tentang kapan terjadinya untuk lebih dapat dipahami secara jelas. Dan tidak dapat diambil informasi/kesimpulan yang tepat terkait visualisasi tersebut.
# 2.
# Justifying the selection of eveyithing we do==>pembuatan visualisasi ini cocok menggunakan linechart karena adanya keadaan naik turun profit yang didaptkan untuk  setiap type dan mungkin ini merupakan salah satu alasan pembuatan visualisasi untuk menunjukkan perbedaan dari profit yang didapatkan.i3.
# Creating accessibility through intuitive design==> mudah diakses akan tetapi tidak langsung mudah dipahami karena judul saja bahkan tidak ada unutk memberikan informasi terkait visualisasi tersebu4. tever Deceive the ReceiverVER=tidak membohonhi user tetapi masih => kurang jelas dalam memberi/menyampaikankan informasi
